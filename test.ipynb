# %%
import pandas as pd

# Load dataset
df = pd.read_excel("/content/global_superstore_2016.xlsx")

# %%
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()

total_cost = total_sales - total_profit
print("Total Cost:", total_cost)
# Out:
# Total Cost: 11175044.6186

# %%
india_profit = df[df["Country"] == "India"]["Profit"].sum()
print("Total Profit in India:", india_profit)
# Out:
# Total Profit in India: 129050.595

# %%
# Create Cost column
df["Cost"] = df["Sales"] - df["Profit"]

# Group by country and calculate total cost
country_cost = df.groupby("Country")["Cost"].sum().sort_values()

# Get 5th country from bottom
fifth_country = country_cost.index[4]
print("5th country on the basis of cost:", fifth_country)
# Out:
# 5th country on the basis of cost: Armenia

# %%
import pandas as pd

df = pd.read_excel("/mnt/data/global_superstore_2016 (1).xlsx")

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Year'] = df['Order Date'].dt.year

sales_2015 = df[df['Year'] == 2015]['Sales'].sum()

print("Total Sales in 2015:", round(sales_2015, 2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1891875853.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("/mnt/data/global_superstore_2016 (1).xlsx")
#       4
#       5 df['Order Date'] = pd.to_datetime(df['Order Date'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
sales_2015 = df[df["Order Date"].dt.year == 2015]["Sales"].sum()
print("Total Sales in 2015:", round(sales_2015))
# Out:
# Total Sales in 2015: 4299866

# %%
sales_2014 = df[df["Order Date"].dt.year == 2014]["Sales"].sum()

# %%
difference = sales_2015 - sales_2014
print("Difference of 2015 and 2014 sales:", round(difference, 2))
# Out:
# Difference of 2015 and 2014 sales: 894119.42

# %%
china_2015_qty = df[
    (df["Order Date"].dt.year == 2015) &
    (df["Country"] == "China")
]["Quantity"].sum()

print("China 2015 Total Quantity Sold:", china_2015_qty)
# Out:
# China 2015 Total Quantity Sold: 2293

# %%
total_discount = (df["Sales"] * df["Discount"]).sum()
print(total_discount)
# Out:
# 1346352.04021416

# %%
total_qty = df[df["Country"].isin(["China", "Australia"])]["Quantity"].sum()
print(total_qty)
# Out:
# 17754

# %%
july_2015 = df[(df["Order Date"].dt.year == 2015) &
               (df["Order Date"].dt.month == 7)]

sales = july_2015["Sales"].sum()
profit = july_2015["Profit"].sum()
cost = sales - profit

print(sales, profit, cost)
# Out:
# 258705.68048 28035.87258 230669.8079

# %%
consumer_df = df[df["Segment"] == "Consumer"]

# %%
total_orders_consumer = consumer_df["Order ID"].nunique()

print("Total number of orders in Consumer Segment:", total_orders_consumer)
# Out:
# Total number of orders in Consumer Segment: 13291

# %%
consumer_df = df[df["Segment"] == "Consumer"]

# %%
total_orders_consumer = consumer_df.shape[0]

print("Total number of orders in Consumer Segment:", total_orders_consumer)
# Out:
# Total number of orders in Consumer Segment: 26518

# %%
filtered_df = df[df["Country"].isin(["China", "Australia"])]

# %%
total_quantity = filtered_df["Quantity"].sum()

print("Total quantity in China and Australia:", total_quantity)
# Out:
# Total quantity in China and Australia: 17754

# %%
df["Country"] = df["Country"].astype(str).str.strip()

# Ensure Quantity is numeric
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")

# Filter China and Australia ONLY
china_aus_df = df[df["Country"].isin(["China", "Australia"])]

# Sum quantity
total_quantity = china_aus_df["Quantity"].sum()

print("Total quantity in China and Australia:", int(total_quantity))
# Out:
# Total quantity in China and Australia: 17754

# %%
import pandas as pd

df = pd.read_excel("/content/global_superstore_2016.xlsx")
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Country"] = df["Country"].astype(str).str.strip()
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")

# %%
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_cost = total_sales - total_profit
total_cost
# Out:
# np.float64(11175044.6186)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_excel("/content/global_superstore_2016.xlsx")

# Calculate totals
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_cost = total_sales - total_profit   # 11175044.6186

# Data for graph
labels = ["Total Sales", "Total Profit", "Total Cost"]
values = [total_sales, total_profit, total_cost]

# Plot bar chart
plt.figure()
plt.bar(labels, values)
plt.title("Total Sales vs Profit vs Cost")
plt.xlabel("Metrics")
plt.ylabel("Amount")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("global_superstore_2016.xlsx")

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month

print("===== MCQ ANSWERS =====")

total_cost = df['Sales'].sum() - df['Profit'].sum()
print("1. Total Cost:", total_cost)

plt.figure()
df[['Sales','Profit']].sum().plot(kind='bar')
plt.title("Total Sales vs Profit")
plt.show()
profit_india = df[df['Country']=="India"]['Profit'].sum()
print("2. Total Profit in India:", profit_india)

plt.figure()
df[df['Country']=="India"].groupby('Year')['Profit'].sum().plot(kind='bar')
plt.title("India Profit by Year")
plt.show()
cost_country = (
    df.groupby('Country')
    .apply(lambda x: x['Sales'].sum() - x['Profit'].sum())
    .sort_values(ascending=False)
)
print("3. 5th Country by Cost:", cost_country.index[4])

plt.figure()
cost_country.head(10).plot(kind='bar')
plt.title("Top 10 Countries by Cost")
plt.show()
sales_2015 = df[df['Year']==2015]['Sales'].sum()
print("4. Total Sales in 2015:", sales_2015)

plt.figure()
df.groupby('Year')['Sales'].sum().plot(kind='bar')
plt.title("Sales by Year")
plt.show()
sales_2014 = df[df['Year']==2014]['Sales'].sum()
print("5. Sales Difference:", sales_2015 - sales_2014)
china_2015_qty = df[(df['Country']=="China") & (df['Year']==2015)]['Quantity'].sum()
print("6. China 2015 Quantity:", china_2015_qty)

plt.figure()
df[df['Country']=="China"].groupby('Year')['Quantity'].sum().plot(kind='bar')
plt.title("China Quantity by Year")
plt.show()
total_discount = df['Discount'].sum()
print("7. Total Discount:", total_discount)

plt.figure()
df.groupby('Year')['Discount'].sum().plot(kind='bar')
plt.title("Discount by Year")
plt.show()
china_aus_qty = (
    df[df['Country']=="China"]['Quantity'].sum() +
    df[df['Country']=="Australia"]['Quantity'].sum()
)
print("8. China + Australia Quantity:", china_aus_qty)

plt.figure()
df[df['Country'].isin(["China","Australia"])].groupby('Country')['Quantity'].sum().plot(kind='bar')
plt.title("China vs Australia Quantity")
plt.show()

july_2015 = df[(df['Year']==2015) & (df['Month']==7)]
july_profit = july_2015['Profit'].sum()
july_cost = july_2015['Sales'].sum() - july_2015['Profit'].sum()

print("9. July 2015 Profit:", july_profit)
print("   July 2015 Cost:", july_cost)

plt.figure()
july_2015[['Sales','Profit']].sum().plot(kind='bar')
plt.title("July 2015 Sales vs Profit")
plt.show()
consumer_orders = df[df['Segment']=="Consumer"]['Order ID'].nunique()
print("10. Consumer Orders:", consumer_orders)

plt.figure()
df['Segment'].value_counts().plot(kind='bar')
plt.title("Orders by Segment")
plt.show()90
# Out:
# ===== MCQ ANSWERS =====
# 1. Total Cost: 11175044.6186
# 2. Total Profit in India: 129050.595
# 3. 5th Country by Cost: Germany
# /tmp/ipython-input-1300089866.py:34: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x['Sales'].sum() - x['Profit'].sum())
# 4. Total Sales in 2015: 4299865.870560001
# 5. Sales Difference: 894119.4211800005
# 6. China 2015 Quantity: 2293
# 7. Total Discount: 7329.727999999999
# 8. China + Australia Quantity: 17754
# 9. July 2015 Profit: 28035.87258
#    July 2015 Cost: 230669.8079
# 10. Consumer Orders: 13291
